# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pickle 
import matplotlib.pyplot as plt
import pandas as pd
import os
import glob
from collections import defaultdict
import yaml
from torch.utils.data import Dataset, DataLoader
import random
import math
import sys
import seaborn as sb
# D:\projects\spurious feature\code\boolean_spurious_correlation\main\src\py_files
# "/boolean_spurious_correlation/main/src/py_files"
sys.path.append(r"D:\projects\spurious feature\code\boolean_spurious_correlation\main\src\py_files")
from utils import *
from models import *
from dataset_utils import *
from dataset import *
from training import *
from models import *
from playground_algo import *
from plot_utils import *
from read_data_utils import *
from torchvision import transforms, datasets

# %%
mnist.class_to_idx
# Out:
# {'0 - zero': 0,
#  '1 - one': 1,
#  '2 - two': 2,
#  '3 - three': 3,
#  '4 - four': 4,
#  '5 - five': 5,
#  '6 - six': 6,
#  '7 - seven': 7,
#  '8 - eight': 8,
#  '9 - nine': 9}

# %%
t_dict = dict()
for k,v in mnist.class_to_idx.items():
    m_key = k.split()[2]
    t_dict[m_key] = v

# %%
t_dict.keys()
# Out:
# dict_keys(['zero', 'one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight', 'nine'])

# %%
cifar.class_to_idx.keys()
# Out:
# dict_keys(['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'])

# %%
fashion.class_to_idx.keys()
# Out:
# dict_keys(['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'])

# %%
interested_exps = [ "cat-dog_truck-automobile"]
dir_path = r"D:\projects\spurious feature\code\boolean_spurious_correlation\main\out\new_domino"
#dir_path = r"/workspaces/boolean_spurious_correlation/main/out/new"
res_stats = read_real(dir_path, interested_exps)

# %%
exp = "cat-dog_truck-automobile"
training = pd.DataFrame(res_stats[exp]["core_training_res_list"])
testing = pd.DataFrame(res_stats[exp]["pop_stats_list"])
groups = pd.DataFrame(res_stats[exp]["group_stats_list"])

# %%
plt.plot(accuracy_to_correlation(testing["population_core_acc"][:100]))
plt.plot(accuracy_to_correlation(testing["population_spurious_acc"][:100]))

# %%
plt.plot(testing["core_info"])
plt.plot(testing["spurious_info"])
